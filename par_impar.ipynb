# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminepo/Algoritmos/blob/main/par_impar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Digite um número inteiro positivo: "))

if num % 2 == 0:
  x = num**2
  print(f"{num}² = {x}")

else:
  y = num**3
  print(f"{num}³ = {y}")
