# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminepo/Algoritmos/blob/main/progressao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=0
y=1
quant=1
termo1=float(input("Digite o primeiro termo: "))
termo2=float(input("Digite a quantidade de termos: "))
razao=float(input("Digite o valor da razão: "))
while quant<=termo2:
  print(f"Valor do termo {y}: {termo1}")
  termo1+=razao
  quant+=1
  y+=1
# Out:
# Digite o primeiro termo: 2
# Digite a quantidade de termos: 4
# Digite o valor da razão: 5
# Valor do termo 1: 2.0
# Valor do termo 2: 7.0
# Valor do termo 3: 12.0
# Valor do termo 4: 17.0
