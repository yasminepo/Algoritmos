# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminepo/Algoritmos/blob/main/quest%C3%A3o1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
preco=float(input("Digite o preço do produto: "))
quantidade=float(input("Digite a quantidade comprada: "))
total=preco * quantidade
print("Valor total da compra: ", total)
# Out:
# Digite o preço do produto: 2
# Digite a quantidade comprada: 2
# Valor total da compra:  4.0
