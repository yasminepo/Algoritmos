# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminepo/Algoritmos/blob/main/Medicamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3
nome=input("Digite o seu nome: ")
while x<4:
 senha=input("Digite a sua senha: ")
 x=x-1
 if senha=="123456":
  print(f"Olá, {nome}. Seja bem vindo ao nosso banco!")
  break
 else:
  if x==1:
   print(f"Senha incorreta! Você ainda tem {x} tentativa")
  elif x==0:
   print("Sua senha foi bloqueada! Por favor, dirija-se a um de nossos caixas.")
   break
  else:
   print(f"Senha incorreta! Você ainda tem {x} tentativas")
