# %%
num1 = float(input("Digite o primeiro número positivo: "))
num2 = float(input("Digite o segundo número positivo: "))

print("1. Média ponderada (pesos 2 e 3)")
print("2. Quadrado da soma dos 2 números")
print("3. Cubo do menor número")
x = input("Escolha uma opção: ")

if x == "1":
    media = (num1*2+num2*3)/6
    print("Resultado da média ponderada: ", media)

elif x == "2":
    resultado = (num1+num2)**2
    print("Quadrado da soma: ", resultado)

elif x == "3":
    if num1 < num2:
       v1=num1**3
       print("Resultado do cubo: ", v1)
    else:
       v2=num2**3
       print("Resultado do cubo: ", v2)

else:
    print("Opção inválida")
# Out:
# Digite o primeiro número positivo: 2
# Digite o segundo número positivo: 3.
# 1. Média ponderada (pesos 2 e 3)
# 2. Quadrado da soma dos 2 números
# 3. Cubo do menor número
# Escolha uma opção: 5
# Opção inválida
